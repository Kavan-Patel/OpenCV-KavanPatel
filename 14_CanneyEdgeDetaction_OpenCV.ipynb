# %% [markdown]
# # Canney Edge Detaction process
# 1. Noise reduction   //Apply gausian filter
# 2. Gradient Calculation   //Find Intensity gredient of the image
# 3. Non-Maximum suppression   //
# 4. Dobled Threshould     //To determine potential edges
# 5. Edge Tracking by Hysteresis

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
# def nothing(x):
#     pass

img=cv.imread('messi5.jpg',0)
img=cv.cvtColor(img, cv.COLOR_BGR2RGB)
# cv.namedWindow('tik')
# cv.createTrackbar('Track','tik',0,255,nothing)

canny= cv.Canny(img,100,300)

images=[img,canny]
titles=['Image',"Canny"]

plt.figure(figsize=(15,15))
for i in range(2):
    plt.subplot(1,2,i+1), plt.imshow(images[i],'gray')
    plt.xticks([]), plt.yticks([])
    plt.title(titles[i])

plt.show()
